# %%
import pandas as pd
import re
import codecs
from sklearn.feature_extraction.text import TfidfVectorizer
from datasketch import MinHashLSHForest, MinHash
from itertools import combinations
from collections import defaultdict
import csv
import math
import hashlib

# %%
songs = pd.read_csv('./songs.csv')
lyrics = pd.read_csv('./lyrics.csv')

# %% [markdown]
# ### 1. TF-IDF

# %%
def splitwords(row):
    lyric = codecs.decode(row['lyrics'], "unicode_escape")
    lyric = re.sub(r'[ \u00A0\u1680\u2000-\u200A\u202F\u205F\u3000]', ' ', lyric)
    lyric = re.sub(r"(?<!\w)'(?!s\s|t\s|re\s|ve\s|m\s|d\s|ll\s|nt\s)", "", lyric)
    lyric = re.sub(r"\', ", " ", lyric)
    lyric = re.sub(r',', '', lyric)
    lyric = re.sub(r'\]', '', re.sub(r'\[', '', lyric))
    lyric = re.sub(r'\"', '', lyric)
    return lyric

# %%
lyrics['formatted_lyrics'] = lyrics.apply(splitwords, axis=1)
all_lyrics = lyrics['formatted_lyrics'].tolist()
all_songs = lyrics['track_name'].tolist()

# initialize a TfidfVectorizer object
vectorizer = TfidfVectorizer(stop_words='english')

# # fit_transform the lyrics to obtain matrix representation of TF-IDF scores
tfidf_matrix = vectorizer.fit_transform(all_lyrics)

# feature names are the 
feature_names = vectorizer.get_feature_names_out()

all_sig_words = []
all_scores = []

for i in range(len(all_lyrics)):
    tfidf_scores = tfidf_matrix[i].toarray()[0]
    max_ind = tfidf_scores.argmax()
    sig_word = feature_names[max_ind]
    max_score = max(tfidf_scores)

    all_sig_words.append(sig_word)
    all_scores.append(max_score)

tfidf = pd.DataFrame({'track_name': all_songs, 'significant_word': all_sig_words, 'score': all_scores})
tfidf
# Out:
#                                            track_name significant_word  \
# 0                                             happier            happy
# 1                                                Solo              let
# 2                                     Search & Rescue             mami
# 3                     WAIT FOR U (feat. Drake & Tems)            vocãª
# 4                                          Time Flies          outside
# 5                                        ball w/o you             ball
# 6                                               a lot              lot
# 7                                              Runnin           runnin
# 8                                     Glock In My Lap               21
# 9   Maria I'm Drunk (feat. Justin Bieber & Young T...         bãªbados
# 10                                           Location              arm
# 11                                        Out thë way              ooh
# 12                                                Sky            slatt
# 13                                        Money Trees             bish
# 14                                     No Role Modelz            saved
# 15                      Father Stretch My Hands Pt. 1               na
# 16        Jukebox Joints (feat. Joe Fox & Kanye West)               eu
# 17                                     Feeling Myself              jag
# 18                                               Amen              jag
# 19                               Ambitionz Az A Ridah            ridah
# 20                              What's The Difference       difference
# 21                                         My Name Is             chka
# 22                                           P.I.M.P.         cadillac
# 23  Too Many Nights (feat. Don Toliver & with Future)             feat
# 24                                               Solo              let
# 25                                    Search & Rescue             mami
# 26                    WAIT FOR U (feat. Drake & Tems)            vocãª
# 27                                      Gin and Juice             mind
# 28                            Real Muthaphuckkin' G's         ruthless
# 29                              It Ain't Hard to Tell             like
# 30                                       Still D.R.E.          corners
# 31                                           Kill You             kill
# 32                       Who Shot Ya? - 2005 Remaster             feat
# 33                                            Changes              way
# 34                                       Bitch Please              ayo
# 35                                   The Next Episode               da
# 36                                               DNA.              dna
# 37                                  Where The Hood At               yo
# 38                                       Why We Thugs             hood
# 39                                The Real Slim Shady            shady
# 40                                      Gotta Have It             need
# 41                         Who Am I (What’s My Name)?             dogg
# 42                      All Eyez On Me (ft. Big Syke)               eu
# 43                             Cleanin' Out My Closet            meant
# 44                                  Patiently Waiting               50
# 45                                           Fuck You          husband
# 46                                           Get Down             gave
# 47                                            Alright          alright
# 48                                            Lay Low              lay
# 49                                      Ghetto Gospel           ghetto
# 50                                               Stan              bad
# 51                                        No Vaseline          getting
# 52                                           Hustlin'          hustlin
#
#        score
# 0   0.447475
# 1   0.432551
# 2   0.436402
# 3   0.568177
# 4   0.441883
# 5   0.652065
# 6   0.701501
# 7   0.885889
# 8   0.589367
# 9   0.427328
# 10  0.586070
# 11  0.444019
# 12  0.640392
# 13  0.638043
# 14  0.480417
# 15  0.440455
# 16  0.499194
# 17  0.423060
# 18  0.728856
# 19  0.573428
# 20  0.450845
# 21  0.766001
# 22  0.413382
# 23  0.908567
# 24  0.432551
# 25  0.436402
# 26  0.568177
# 27  0.363529
# 28  0.424055
# 29  0.266891
# 30  0.306471
# 31  0.406943
# 32  0.786664
# 33  0.507202
# 34  0.472826
# 35  0.499694
# 36  0.693994
# 37  0.648758
# 38  0.425127
# 39  0.520558
# 40  0.587205
# 41  0.414421
# 42  0.390263
# 43  0.416719
# 44  0.536907
# 45  0.307326
# 46  0.129113
# 47  0.734661
# 48  0.401237
# 49  0.343305
# 50  0.238210
# 51  0.389166
# 52  0.790855

# %% [markdown]
# ### 2. Map-Reduce

# %% [markdown]
# Verify this result with Hadoop MapReduce computation.

# %%
df = songs[['playlist_uri', 'track_name', 'id', 'popularity']]
df.groupby('playlist_uri').mean(numeric_only=True)
# Out:
#                                          popularity
# playlist_uri
# spotify:playlist:0Blc7H0vclyoZYpkfN5oFn   77.416667
# spotify:playlist:0cNYHRGCv0cyQjeLblv2Oa   75.666667
# spotify:playlist:0pYKCDEitaEtWRzYJX0Hwy   62.127273
# spotify:playlist:0uRHOYgXiR3l9BwssW7IMH   78.727273
# spotify:playlist:0wO7kqupC0YZBLlJsQwceS   52.200000
# ...                                             ...
# spotify:playlist:6MoR16aokakIrchsWepo2x   76.920000
# spotify:playlist:6ySrUrNk0prJL8szfuiuIA   68.535714
# spotify:playlist:72lmW37G35cATUdAiDPKdj   79.428571
# spotify:playlist:7J8BhUluUUOFKMv9GkmfbI   72.888889
# spotify:playlist:7aQsuG5GIEg4gkcqLRhapC   64.000000
#
# [70 rows x 1 columns]

# %% [markdown]
# ### 3. LSH

# %%
feature_vectors = songs[['id','danceability','speechiness','acousticness','instrumentalness','liveness']]
feature_vectors = feature_vectors.drop_duplicates()
feature_vectors.drop('id', inplace=True, axis=1)

# %%
lsh = MinHashLSHForest(num_perm=128)

for i in range(len(feature_vectors)):
    song_features = feature_vectors.iloc[i]
    minhash = MinHash(num_perm=128)  # Adjust the number of permutations as needed

    # Hash the song features
    for feature in song_features:
        minhash.update(str(feature).encode('utf-8'))

    # Index the song in LSH model
    lsh.add(str(i), minhash)

lsh.index()

query_song_index = 0
query_song_features = feature_vectors.iloc[query_song_index]

# Create MinHash for the query song
query_minhash = MinHash(num_perm=128)  # Adjust the number of permutations as needed

# Hash the query song features
for feature in query_song_features:
    query_minhash.update(str(feature).encode('utf-8'))

# Query the LSH model
result = lsh.query(query_minhash, k=10)  # Retrieve the top 10 similar songs

# Retrieve the actual similar songs from the dataset

songs[['track_name','danceability','speechiness','acousticness','instrumentalness','liveness']].iloc[map(int, result)]
# similar_songs
# Out:
#                                track_name  danceability  speechiness  \
# 1248                              Control        0.5990       0.0314
# 801                             You Right        0.8280       0.0565
# 198   Lost in the Fire (feat. The Weeknd)        0.6580       0.0363
# 1448                               Ho Hey        0.6850       0.0304
# 2312           Can't Help Falling in Love        0.3960       0.0275
# 1803                    The Frozen Planet        0.0607       0.0432
# 2054            Teenage Dirtbag - Sped Up        0.6630       0.0804
# 2041               No Sleep Till Brooklyn        0.7120       0.1280
# 1869                 Too Good At Goodbyes        0.6810       0.0432
# 0                                 happier        0.3950       0.1330
#
#       acousticness  instrumentalness  liveness
# 1248        0.6430          0.000002    0.1490
# 801         0.0164          0.002330    0.0845
# 198         0.0933          0.000927    0.1150
# 1448        0.7940          0.000002    0.0915
# 2312        0.9410          0.000196    0.1050
# 1803        0.6450          0.493000    0.0616
# 2054        0.5140          0.058300    0.1190
# 2041        0.1220          0.000000    0.0538
# 1869        0.6400          0.000000    0.1690
# 0           0.7650          0.000010    0.0839

# %% [markdown]
# ### 4. Bloom Filter

# %%
class BloomFilter:
    def _init_(self, num_items, false_positive_rate):
        self.num_items = num_items
        self.false_positive_rate = false_positive_rate
        self.num_bits = self.calculate_num_bits(num_items, false_positive_rate)
        self.num_hashes = self.calculate_num_hashes(num_items, self.num_bits)
        self.bit_array = [0] * self.num_bits
        print("Number of bits:", self.num_bits)
        self.hash_functions = self.create_hash_functions(self.num_hashes)

    def calculate_num_bits(self, num_items, false_positive_rate):
        numerator = num_items * abs(math.log(false_positive_rate))
        denominator = math.log(2) ** 2
        return int(numerator / denominator)

    def calculate_num_hashes(self, num_items, num_bits):
        numerator = num_bits * math.log(2)
        return max(1, int(numerator / num_items))

    def create_hash_functions(self, num_hashes):
        hash_functions = []
        for seed in range(num_hashes):
            hash_functions.append(self.hash_function(seed))
        return hash_functions

    def hash_function(self, seed):
        def fnv1a_32(data):
            hash_value = 2166136261
            for byte in data:
                hash_value ^= byte
                hash_value *= 16777619
            return hash_value

        def sha256(data):
            return int(hashlib.sha256(data).hexdigest(), 16)

        if seed % 2 == 0:
            return lambda data: fnv1a_32(data.encode())
        else:
            return lambda data: sha256(data.encode())

    def add(self, item):
        for hash_func in self.hash_functions:
            index = hash_func(str(item)) % self.num_bits
            self.bit_array[index] = 1

    def contains(self, item):
        for hash_func in self.hash_functions:
            index = hash_func(str(item)) % self.num_bits
            if self.bit_array[index] == 0:
                return False
        return True


def load_dataset(file_path):
    dataset = []
    with open(file_path, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row
        for row in reader:
            dataset.append(row)
    return dataset


def get_track_info(dataset, song_id):
    for row in dataset:
        if row[2] == song_id:
            track_name = row[0]
            artist = row[1]
            return track_name, artist
    return None, None


dataset_path = 'songs.csv'
dataset = load_dataset(dataset_path)
bloom_filter = BloomFilter(len(dataset), 0.05)


for row in dataset:
    song_id = row[2]
    bloom_filter.add(song_id)

# Search for a song in the bloom filter
# 4lH6nENd1y81jp7Yt9lTBX

search_song_id = '2Hh3ETdQKrmSI3QS0hme7g'
if bloom_filter.contains(search_song_id):
    track_name, artist = get_track_info(dataset, search_song_id)
    if track_name and artist:
        print(
            f"The song with ID '{search_song_id}' is likely in the playlist.")
        print(f"Track Name: {track_name}")
        print(f"Artist: {artist}")
    else:
        print(
            f"Failed to retrieve track name and artist for song ID '{search_song_id}'.")
else:
    print(f"The song with ID '{search_song_id}' is not in the playlist.")

# %% [markdown]
# ### 5. PCY Algorithm

# %%
# 1. Representing songs as a set of transactions
playlistset = songs['playlist_uri'].drop_duplicates()
transactions = defaultdict(set)
for playlist in playlistset:
    transactions[playlist] = set(songs.loc[songs['playlist_uri'] == playlist, 'id'].tolist())

# %%
# 2. count of each item and generate candidate itemset
single_item_frequency = defaultdict(int)
for transaction in transactions:
    for item in transactions[transaction]:
        single_item_frequency[item] += 1
sc = 3
candidate_item_set = {k: v for k, v in single_item_frequency.items() if single_item_frequency[k] >= sc}
len(candidate_item_set)
# Out:
# 215

# %%
num_buckets = 223

# Filtering step: Identify frequent individual songs
frequent_songs = candidate_item_set

# Pair counting step: Count frequent pairs
frequent_pairs = defaultdict(int)
for transaction in transactions.values():
    # Generate candidate pairs of frequent songs
    frequent_candidate_pairs = combinations([song for song in transaction if song in frequent_songs], 2)

    # Hash pairs and increment counts for frequent pairs
    for pair in frequent_candidate_pairs:
        pair_hash = hash(pair) % num_buckets  # Use a hash function to map the pair to a specific bucket
        frequent_pairs[pair] += 1

# Filter frequent pairs based on support threshold
frequent_pairs = {pair: count for pair, count in frequent_pairs.items() if count >= sc}

frequent_pairs
# Out:
# {('7MXVkk9YMctZqd1Srtv4MB', '76FZM38RC8XaAjJ77CVTNe'): 3,
#  ('7MXVkk9YMctZqd1Srtv4MB', '09mEdoA6zrmBPgTEN5qXmN'): 4,
#  ('6ocbgoVGwYJhOv1GgI9NsF', '09mEdoA6zrmBPgTEN5qXmN'): 3,
#  ('6ocbgoVGwYJhOv1GgI9NsF', '2nMeu6UenVvwUktBCpLMK9'): 3,
#  ('09mEdoA6zrmBPgTEN5qXmN', '2nMeu6UenVvwUktBCpLMK9'): 3,
#  ('68Dni7IE4VyPkTOH9mRWHr', '6PGoSes0D9eUDeeAafB2As'): 3,
#  ('68Dni7IE4VyPkTOH9mRWHr', '7xoUc6faLbCqZO6fQEYprd'): 3,
'0nJW01T7XtvILxQgC5J7Wh'): 3,
#  ('698ItKASDavgwZ3WjaWjtz', '3LlmKSHR3Rs0Y3KHQLAYDk'): 3,
#  ('698ItKASDavgwZ3WjaWjtz', '0nrRP2bk19rLc0orkWPQk2'): 3,
#  ('698ItKASDavgwZ3WjaWjtz', '0ct6r3EGTcMLPtrXHDvVjc'): 3,
#  ('698ItKASDavgwZ3WjaWjtz', '2P4OICZRVAQcYAV2JReRfj'): 3,
#  ('3KkXRkHbMCARz0aVfEt68P', '0ct6r3EGTcMLPtrXHDvVjc'): 4,
#  ('3KkXRkHbMCARz0aVfEt68P', '2P4OICZRVAQcYAV2JReRfj'): 3,
#  ('3LlmKSHR3Rs0Y3KHQLAYDk', '0nrRP2bk19rLc0orkWPQk2'): 3,
#  ('3LlmKSHR3Rs0Y3KHQLAYDk', '0ct6r3EGTcMLPtrXHDvVjc'): 3,
#  ('3LlmKSHR3Rs0Y3KHQLAYDk', '2P4OICZRVAQcYAV2JReRfj'): 3,
#  ('0ct6r3EGTcMLPtrXHDvVjc', '2P4OICZRVAQcYAV2JReRfj'): 3,
#  ('2FY7b99s15jUprqC0M5NCT', '2RSHsoi04658QL5xgQVov3'): 3,
#  ('2FY7b99s15jUprqC0M5NCT', '6Qn5zhYkTa37e91HC1D7lb'): 4,
#  ('0HqZX76SFLDz2aW8aiqi7G', '3USxtqRwSYz57Ewm6wWRMp'): 3,
#  ('2RSHsoi04658QL5xgQVov3', '3USxtqRwSYz57Ewm6wWRMp'): 3,
#  ('2RSHsoi04658QL5xgQVov3', '6Qn5zhYkTa37e91HC1D7lb'): 3,
#  ('0VjIjW4GlUZAMYd2vXMi3b', '3KkXRkHbMCARz0aVfEt68P'): 4,
#  ('0VjIjW4GlUZAMYd2vXMi3b', '3USxtqRwSYz57Ewm6wWRMp'): 3,
#  ('3KkXRkHbMCARz0aVfEt68P', '3USxtqRwSYz57Ewm6wWRMp'): 3,
#  ('5Ohxk2dO5COHF1krpoPigN', '1KxwZYyzWNyZSRyErj2ojT'): 3,
#  ('5Ohxk2dO5COHF1krpoPigN', '7vRriwrloYVaoAe3a9wJHe'): 3,
#  ('5Ohxk2dO5COHF1krpoPigN', '2BOqDYLOJBiMOXShCV1neZ'): 3,
#  ('5Ohxk2dO5COHF1krpoPigN', '2RttW7RAu5nOAfq6YFvApB'): 3,
#  ('5Ohxk2dO5COHF1krpoPigN', '4G92yYrUs0cvY7G41YRI0z'): 3,
#  ('5Ohxk2dO5COHF1krpoPigN', '7B5Npv8NjjTCzk8PLpU66h'): 3,
#  ('60iSKGrGazRzICtMjADNSM', '0u2P5u6lvoDfwTYjAADbn4'): 3,
#  ('60iSKGrGazRzICtMjADNSM', '4G92yYrUs0cvY7G41YRI0z'): 3,
#  ('60iSKGrGazRzICtMjADNSM', '43zdsphuZLzwA9k4DJhU0I'): 3,
#  ('60iSKGrGazRzICtMjADNSM', '1mXVgsBdtIVeCLJnSnmtdV'): 3,
#  ('1KxwZYyzWNyZSRyErj2ojT', '7vRriwrloYVaoAe3a9wJHe'): 3,
#  ('1KxwZYyzWNyZSRyErj2ojT', '2BOqDYLOJBiMOXShCV1neZ'): 3,
#  ('1KxwZYyzWNyZSRyErj2ojT', '2RttW7RAu5nOAfq6YFvApB'): 3,
#  ('1KxwZYyzWNyZSRyErj2ojT', '0nJW01T7XtvILxQgC5J7Wh'): 3,
#  ('1KxwZYyzWNyZSRyErj2ojT', '4G92yYrUs0cvY7G41YRI0z'): 3,
#  ('1KxwZYyzWNyZSRyErj2ojT', '43zdsphuZLzwA9k4DJhU0I'): 3,
#  
#  ('0pqnGHJpmpxLKifKRmU6WP', '54ipXppHLA8U4yqpOFTUhr'): 3,
#  ('0pqnGHJpmpxLKifKRmU6WP', '3CIyK1V4JEJkg02E4EJnDl'): 3,
#  ('0pqnGHJpmpxLKifKRmU6WP', '6Qn5zhYkTa37e91HC1D7lb'): 3,
#  ('2FY7b99s15jUprqC0M5NCT', '1zB4vmk8tFRmM9UULNzbLB'): 3,
#  ('0u2P5u6lvoDfwTYjAADbn4', '3USxtqRwSYz57Ewm6wWRMp'): 3,
#  ('54ipXppHLA8U4yqpOFTUhr', '3CIyK1V4JEJkg02E4EJnDl'): 3,
#  ('54ipXppHLA8U4yqpOFTUhr', '1zB4vmk8tFRmM9UULNzbLB'): 3,
#  ('6Qn5zhYkTa37e91HC1D7lb', '1zB4vmk8tFRmM9UULNzbLB'): 3,
#  ('0u2P5u6lvoDfwTYjAADbn4', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('7vRriwrloYVaoAe3a9wJHe', '2qxmye6gAegTMjLKEBoR3d'): 3,
#  ('2BOqDYLOJBiMOXShCV1neZ', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('2RttW7RAu5nOAfq6YFvApB', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('7qEHsqek33rTcFNT9PFqLf', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('2qxmye6gAegTMjLKEBoR3d', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('43zdsphuZLzwA9k4DJhU0I', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('1ZMiCix7XSAbfAJlEZWMCp', '1mXVgsBdtIVeCLJnSnmtdV'): 4,
#  ('4xqrdfXkTW4T0RauPLv3WA', '3USxtqRwSYz57Ewm6wWRMp'): 3,
#  ('55Am8neGJkdj2ADaM3aw5H', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('5CZ40GBx1sQ9agT82CLQCT', '45bE4HXI0AwGZXfZtMp8JR'): 3,
#  ('5CZ40GBx1sQ9agT82CLQCT', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('45bE4HXI0AwGZXfZtMp8JR', '1ZMiCix7XSAbfAJlEZWMCp'): 3,
#  ('3h4T9Bg8OVSUYa6danHeH5', '0ct6r3EGTcMLPtrXHDvVjc'): 3,
#  ('3KkXRkHbMCARz0aVfEt68P', '2ZRo7axmMPeSVUvDbGkJah'): 3,
#  ('3zHq9ouUJQFQRf3cm1rRLu', '0ct6r3EGTcMLPtrXHDvVjc'): 3,
#  ('3QGsuHI8jO1Rx4JWLUh9jd', '2K87XMYnUMqLcX3zvtAF4G'): 3,
#  ('6RUKPb4LETWmmr3iAEQktW', '2K87XMYnUMqLcX3zvtAF4G'): 3,
#  ('0qOnSQQF0yzuPWsXrQ9paz', '0ct6r3EGTcMLPtrXHDvVjc'): 3,
#  ('0ct6r3EGTcMLPtrXHDvVjc', '5O2P9iiztwhomNh8xkR9lJ'): 3,
#  ('6v3KW9xbzN5yKLt9YKDYA2', '3QGsuHI8jO1Rx4JWLUh9jd'): 3}
